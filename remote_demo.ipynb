# %% [markdown]
# # Remote Server Notebook Demo
# This notebook is intentionally simple for a remote server tutorial.

# %%
print('Hello from Jupyter on the remote server')

# %%
def multiply(a, b):
    return a * b

multiply(6, 7)
